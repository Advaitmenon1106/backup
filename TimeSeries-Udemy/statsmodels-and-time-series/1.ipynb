# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.filters.hp_filter import hpfilter

# %%
df = pd.read_csv('macrodata.csv', index_col='Unnamed: 0')

# %%
df.head()
# Out:
#             year  quarter   realgdp  realcons  realinv  realgovt  realdpi  \
# 3/31/1959   1959        1  2710.349    1707.4  286.898   470.045   1886.9
# 6/30/1959   1959        2  2778.801    1733.7  310.859   481.301   1919.7
# 9/30/1959   1959        3  2775.488    1751.8  289.226   491.260   1916.4
# 12/31/1959  1959        4  2785.204    1753.7  299.356   484.052   1931.3
# 3/31/1960   1960        1  2847.699    1770.5  331.722   462.199   1955.5
#
#               cpi     m1  tbilrate  unemp      pop  infl  realint
# 3/31/1959   28.98  139.7      2.82    5.8  177.146  0.00     0.00
# 6/30/1959   29.15  141.7      3.08    5.1  177.830  2.34     0.74
# 9/30/1959   29.35  140.5      3.82    5.3  178.657  2.74     1.09
# 12/31/1959  29.37  140.0      4.33    5.6  179.386  0.27     4.06
# 3/31/1960   29.54  139.6      3.50    5.2  180.007  2.31     1.19

# %%
df.index = pd.to_datetime(df.index)

# %%
df.head()
# Out:
#             year  quarter   realgdp  realcons  realinv  realgovt  realdpi  \
# 1959-03-31  1959        1  2710.349    1707.4  286.898   470.045   1886.9
# 1959-06-30  1959        2  2778.801    1733.7  310.859   481.301   1919.7
# 1959-09-30  1959        3  2775.488    1751.8  289.226   491.260   1916.4
# 1959-12-31  1959        4  2785.204    1753.7  299.356   484.052   1931.3
# 1960-03-31  1960        1  2847.699    1770.5  331.722   462.199   1955.5
#
#               cpi     m1  tbilrate  unemp      pop  infl  realint
# 1959-03-31  28.98  139.7      2.82    5.8  177.146  0.00     0.00
# 1959-06-30  29.15  141.7      3.08    5.1  177.830  2.34     0.74
# 1959-09-30  29.35  140.5      3.82    5.3  178.657  2.74     1.09
# 1959-12-31  29.37  140.0      4.33    5.6  179.386  0.27     4.06
# 1960-03-31  29.54  139.6      3.50    5.2  180.007  2.31     1.19

# %%
df['realgdp'].plot()
# Out:
# <AxesSubplot:>

# %%
gdp_cyc, trend= hpfilter(df['realgdp'], lamb=1600)

# %%
trend
# Out:
# 1959-03-31     2670.837085
# 1959-06-30     2698.712468
# 1959-09-30     2726.612545
# 1959-12-31     2754.612067
# 1960-03-31     2782.816333
#                   ...
# 2008-09-30    13222.581545
# 2008-12-31    13249.189472
# 2009-03-31    13274.457706
# 2009-06-30    13299.061073
# 2009-09-30    13323.456243
# Name: realgdp_trend, Length: 203, dtype: float64

# %%
df['realgdp'].plot.line(color='blue');
trend.plot(style='red');

# %%
df['realgdp']['2005-01-01':].plot.line(color='blue');
trend['2005-01-01':].plot(style='red');
