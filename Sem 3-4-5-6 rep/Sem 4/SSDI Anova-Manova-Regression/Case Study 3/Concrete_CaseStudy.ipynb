# %%
concrete = pd.read_csv('Concrete_Data_Yeh.csv')
concrete.head()
# Out:
#    cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0   540.0    0.0     0.0  162.0               2.5           1040.0
# 1   540.0    0.0     0.0  162.0               2.5           1055.0
# 2   332.5  142.5     0.0  228.0               0.0            932.0
# 3   332.5  142.5     0.0  228.0               0.0            932.0
# 4   198.6  132.4     0.0  192.0               0.0            978.4
#
#    fineaggregate  age  csMPa
# 0          676.0   28  79.99
# 1          676.0   28  61.89
# 2          594.0  270  40.27
# 3          594.0  365  41.05
# 4          825.5  360  44.30

# %%
concreteQuant = add_constant(data=concrete.drop(columns=['csMPa']))
concreteQuant
# Out:
#       const  cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0       1.0   540.0    0.0     0.0  162.0               2.5           1040.0
# 1       1.0   540.0    0.0     0.0  162.0               2.5           1055.0
# 2       1.0   332.5  142.5     0.0  228.0               0.0            932.0
# 3       1.0   332.5  142.5     0.0  228.0               0.0            932.0
# 4       1.0   198.6  132.4     0.0  192.0               0.0            978.4
# ...     ...     ...    ...     ...    ...               ...              ...
# 1025    1.0   276.4  116.0    90.3  179.6               8.9            870.1
# 1026    1.0   322.2    0.0   115.6  196.0              10.4            817.9
# 1027    1.0   148.5  139.4   108.6  192.7               6.1            892.4
# 1028    1.0   159.1  186.7     0.0  175.6              11.3            989.6
# 1029    1.0   260.9  100.5    78.3  200.6               8.6            864.5
#
#       fineaggregate  age
# ...

# %%
vif = pd.DataFrame()
vif['Features'] = concreteQuant.columns
vif['VIF'] = [variance_inflation_factor(concreteQuant.values, i) for i in range(len(concreteQuant.columns))]

# %%
vif
# Out:
#            Features          VIF
# 0             const  6731.811539
# 1            cement     7.488944
# 2              slag     7.276963
# 3            flyash     6.170634
# 4             water     7.003957
# 5  superplasticizer     2.963776
# 6   coarseaggregate     5.074617
# 7     fineaggregate     7.005081
# 8               age     1.118367

# %%
concreteQuant.drop(columns='cement', inplace=True)
vif = pd.DataFrame()
vif['Features'] = concreteQuant.columns
vif['VIF'] = [variance_inflation_factor(concreteQuant.values, i) for i in range(len(concreteQuant.columns))]

# %%
vif
# Out:
#            Features          VIF
# 0             const  1685.047629
# 1              slag     1.519528
# 2            flyash     1.398687
# 3             water     3.533371
# 4  superplasticizer     2.963506
# 5   coarseaggregate     2.005235
# 6     fineaggregate     1.847198
# 7               age     1.114155

# %%
fit1 = sm.ols('csMPa~slag+flyash+water+superplasticizer+coarseaggregate+fineaggregate+age+slag*water', data= concrete).fit()
fit1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  csMPa   R-squared:                       0.542
# Model:                            OLS   Adj. R-squared:                  0.538
# Method:                 Least Squares   F-statistic:                     151.0
# Date:                Tue, 28 Mar 2023   Prob (F-statistic):          3.03e-167
# Time:                        17:08:21   Log-Likelihood:                -3959.2
# No. Observations:                1030   AIC:                             7936.
# Df Residuals:                    1021   BIC:                             7981.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...
