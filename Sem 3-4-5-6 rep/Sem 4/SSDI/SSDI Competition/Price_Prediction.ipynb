# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
import statsmodels.formula.api as smf

# %%
df = pd.read_csv("C:/Users/Kavita manoj/Downloads/Price_prediction.csv", na_values='?').dropna()

# %%
df
# Out:
#      symboling  normalized_losses   make fuel_type aspiration num-of-doors  \
# 3            2              164.0   audi       gas        std         four
# 4            2              164.0   audi       gas        std         four
# 6            1              158.0   audi       gas        std         four
# 8            1              158.0   audi       gas      turbo         four
# 10           2              192.0    bmw       gas        std          two
# ..         ...                ...    ...       ...        ...          ...
# 200         -1               95.0  volvo       gas        std         four
# 201         -1               95.0  volvo       gas      turbo         four
# 202         -1               95.0  volvo       gas        std         four
# 203         -1               95.0  volvo    diesel      turbo         four
# 204         -1               95.0  volvo       gas      turbo         four
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df2 = df.drop(columns=['price', 'make', 'fuel_type', 'num-of-doors', 'engine-location', 'engine-type', 'fuel-system', 'aspiration', 'body-style', 'drive-wheels', 'num-of-cylinders'])
df2.corr()
# Out:
#                    symboling  normalized_losses  wheel_base    length  \
# symboling           1.000000           0.518344   -0.520591 -0.336257
# normalized_losses   0.518344           1.000000   -0.060086  0.035541
# wheel_base         -0.520591          -0.060086    1.000000  0.871534
# length             -0.336257           0.035541    0.871534  1.000000
# width              -0.219186           0.109726    0.814991  0.838338
# height             -0.475185          -0.413702    0.555767  0.499251
# curb_weight        -0.251880           0.125858    0.810181  0.871291
# engine_size        -0.109453           0.207820    0.649206  0.725953
# bore               -0.256469          -0.031558    0.578159  0.646318
# stroke             -0.021285           0.063330    0.167449  0.121073
# compression_ratio  -0.138316          -0.127259    0.291431  0.184814
# horsepower         -0.003949           0.290511    0.516948  0.672063
# ...

# %%
dfFinal = df.drop(columns=['make', 'fuel_type', 'num-of-doors', 'engine-location', 'engine-type', 'fuel-system', 'aspiration', 'body-style', 'drive-wheels', 'num-of-cylinders'])
dfFinal['volume'] = df['length']*df['width']*df['height']

# %%
#sns.pairplot(dfFinal.drop(columns='price'))

# %%
fit = smf.ols('price~engine_size*compression_ratio+city_mpg*highway_mpg+length*width*height', data=dfFinal).fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.859
# Method:                 Least Squares   F-statistic:                     75.20
# Date:                Fri, 17 Mar 2023   Prob (F-statistic):           1.29e-57
# Time:                        20:24:21   Log-Likelihood:                -1442.4
# No. Observations:                 159   AIC:                             2913.
# Df Residuals:                     145   BIC:                             2956.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...
