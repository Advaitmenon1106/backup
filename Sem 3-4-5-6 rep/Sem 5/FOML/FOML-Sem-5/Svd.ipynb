# %%
from scipy.linalg import svd
import numpy as np

# %%
A = np.array([[2, 3], [4, 5], [6, 7], [8, 9]])

# %%
A.shape
# Out:
# (4, 2)

# %%
u, sigma, vT = svd(A)

# %%
u
# Out:
# array([[-0.21253081, -0.80921607, -0.40008743, -0.37407225],
#        [-0.37994077, -0.39451871,  0.25463292,  0.79697056],
#        [-0.54735073,  0.02017866,  0.69099646, -0.47172438],
#        [-0.71476069,  0.43487602, -0.54554195,  0.04882607]])

# %%
sigma # gives diagonal elements only
# Out:
# array([16.84393155,  0.53100856])

# %%
vT
# Out:
# array([[-0.64990852, -0.76001245],
#        [ 0.76001245, -0.64990852]])

# %%
from sklearn.datasets import fetch_olivetti_faces
import matplotlib.pyplot as plt

# %%
img= plt.imread('./images/setosa_1.jpeg')

# %%
img
# Out:
# array([[[ 59,  95,  51],
#         [ 59,  95,  51],
#         [ 60,  96,  52],
#         ...,
#         [ 93, 126,  79],
#         [ 95, 131,  85],
#         [ 97, 133,  87]],
#
#        [[ 58,  94,  50],
#         [ 59,  95,  51],
#         [ 59,  95,  51],
#         ...,
#         [ 92, 125,  78],
#         [ 94, 130,  84],
#         [ 96, 132,  86]],
#
#        [[ 57,  93,  49],
#         [ 58,  94,  50],
#         [ 58,  94,  50],
#         ...,
#         [ 91, 124,  77],
#         [ 92, 128,  82],
#         [ 95, 131,  85]],
#
#        ...,
#
#        [[132, 170, 119],
#         [132, 170, 119],
#         [132, 170, 119],
#         ...,
#         [ 84, 121,  77],
#         [ 85, 122,  78],
#         [ 86, 123,  79]],
#
#        [[132, 170, 119],
#         [132, 170, 119],
#         [132, 170, 119],
#         ...,
#         [ 83, 120,  76],
#         [ 85, 122,  78],
#         [ 85, 122,  78]],
#
#        [[132, 170, 119],
#         [132, 170, 119],
#         [132, 170, 119],
# ...

# %%
plt.imshow(img)

# %%
import PIL as pil

# %%
img = pil.Image.open('./images/setosa_1.jpeg').convert('L')

# %%
from sklearn.datasets import fetch_olivetti_faces

# %%
face = fetch_olivetti_faces()['data']
face = face.reshape(4096, 400)

# %%
u, sigma, vT = svd(face)

# %%
# plt.plot(u);

# %%
u.shape
# Out:
# (4096, 4096)

# %%
u[0]
# Out:
# array([-0.01890625,  0.00795082,  0.02666165, ..., -0.01548154,
#        -0.02025192, -0.00824923], dtype=float32)

# %%
u[0].shape
# Out:
# (4096,)

# %%
ureshaped = u[0].reshape(64, 64)

# %%
plt.imshow(ureshaped, cmap=plt.bone())

# %%
ureshaped = u[100].reshape(64, 64)

# %%
plt.imshow(ureshaped, cmap=plt.bone())
