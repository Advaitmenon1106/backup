# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from tensorflow import keras
from keras.datasets import mnist
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
plt.imshow(x_train[0])

# %%
from scipy.linalg import svd

# %%
u, s, v = svd(x_train[0])

# %%
explained_variance = s**2/sum(s**2)

# %%
explained_variance
# Out:
# array([5.6401902e-01, 1.9875181e-01, 9.3107425e-02, 5.1675681e-02,
#        4.1055888e-02, 2.2608370e-02, 1.2780019e-02, 7.8454278e-03,
#        3.0723810e-03, 1.9974967e-03, 1.0492990e-03, 7.6539599e-04,
#        7.1474456e-04, 2.3194897e-04, 1.8302009e-04, 8.2749932e-05,
#        4.9851566e-05, 9.0838666e-06, 3.4049697e-07, 5.0567540e-11,
#        8.9275737e-16, 8.9275737e-16, 8.9275737e-16, 8.9275737e-16,
#        8.9275737e-16, 8.9275737e-16, 8.9275737e-16, 8.9275737e-16],
#       dtype=float32)

# %%
low_rank_img = u[:, :8] @ np.diag(s[:8]) @ v[:8, :]

# %%
fig = plt.figure()
fig.add_subplot(2, 3, 1)
plt.imshow(x_train[0])
fig.add_subplot(2, 3, 2)
plt.imshow(low_rank_img)
