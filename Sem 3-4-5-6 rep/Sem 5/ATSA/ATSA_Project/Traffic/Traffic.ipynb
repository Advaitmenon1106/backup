# %%
import numpy as np
import pandas as pd

# %%
traffic = pd.read_csv('Train.csv', index_col='Datetime', parse_dates=True, dayfirst=True).drop(columns=['ID'])

# %%
traffic
# Out:
#                      Count
# Datetime
# 2012-08-25 00:00:00      8
# 2012-08-25 01:00:00      2
# 2012-08-25 02:00:00      6
# 2012-08-25 03:00:00      2
# 2012-08-25 04:00:00      2
# ...                    ...
# 2014-09-25 19:00:00    868
# 2014-09-25 20:00:00    732
# 2014-09-25 21:00:00    702
# 2014-09-25 22:00:00    580
# 2014-09-25 23:00:00    534
#
# [18288 rows x 1 columns]

# %%
traffic['Count'].plot(figsize=(12, 7))
# Out:
# <Axes: xlabel='Datetime'>
