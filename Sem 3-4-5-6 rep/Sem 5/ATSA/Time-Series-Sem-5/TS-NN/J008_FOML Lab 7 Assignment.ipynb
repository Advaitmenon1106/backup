# %%
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split

# %%
dataset = loadtxt('Advertising.csv',delimiter=',') #data seperated by ,
# split into input x and output y
x = dataset[:,0:4] #all rows,column(features0-3)
y = dataset[:,4]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: could not convert string to float: 'TV'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# c:\Users\Kavita manoj\OneDrive\Desktop\Time-Series-Sem-5\TS-NN\J008_FOML Lab 7 Assignment.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Kavita%20manoj/OneDrive/Desktop/Time-Series-Sem-5/TS-NN/J008_FOML%20Lab%207%20Assignment.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> dataset = loadtxt('Advertising.csv',delimiter=',') #data seperated by ,
#       <a href='vscode-notebook-cell:/c%3A/Users/Kavita%20manoj/OneDrive/Desktop/Time-Series-Sem-5/TS-NN/J008_FOML%20Lab%207%20Assignment.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> # split into input x and output y
#       <a href='vscode-notebook-cell:/c%3A/Users/Kavita%20manoj/OneDrive/Desktop/Time-Series-Sem-5/TS-NN/J008_FOML%20Lab%207%20Assignment.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> x = dataset[:,0:4] #all rows,column(features0-3)
#
# File c:\Users\Kavita manoj\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\npyio.py:1356, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1353 if isinstance(delimiter, bytes):
#    1354     delimiter = delimiter.decode('latin1')
# -> 1356 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1357             converters=converters, skiplines=skiprows, usecols=usecols,
#    1358             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1359             max_rows=max_rows, quote=quotechar)
#    1361 return arr
#
# File c:\Users\Kavita manoj\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\npyio.py:999, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     996     data = _preprocess_comments(data, comments, encoding)
#     998 if read_dtype_via_object_chunks is None:
# --> 999     arr = _load_from_filelike(
#    1000         data, delimiter=delimiter, comment=comment, quote=quote,
#    1001         imaginary_unit=imaginary_unit,
#    1002         usecols=usecols, skiplines=skiplines, max_rows=max_rows,
#    1003         converters=converters, dtype=dtype,
#    1004         encoding=encoding, filelike=filelike,
#    1005         byte_converters=byte_converters)
#    1007 else:
#    1008     # This branch reads the file into chunks of object arrays and then
#    1009     # casts them to the desired actual dtype.  This ensures correct
#    1010     # string-length and datetime-unit discovery (like `arr.astype()`).
#    1011     # Due to chunking, certain error reports are less clear, currently.
#    1012     if filelike:
#
# ValueError: could not convert string 'TV' to float64 at row 0, column 1.

# %%
# Split the data into train and test sets
test_size = 0.25

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size)

# %%
# Normalize the data
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
model = Sequential()
model.add(Dense(12,input_shape=(4,),activation='linear'))
model.add(Dense(8,activation='linear'))
model.add(Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 12)                60
#
#  dense_1 (Dense)             (None, 8)                 104
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 173 (692.00 Byte)
# Trainable params: 173 (692.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error',optimizer='adam',metrics=['mse'])

# %%
#Step 3 - fit the model
model.fit(x_train, y_train, epochs=100,batch_size=10)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 3s 5ms/step - loss: 223.1883 - mse: 223.1883
# Epoch 2/100
# 15/15 [==============================] - 0s 5ms/step - loss: 211.3533 - mse: 211.3533
# Epoch 3/100
# 15/15 [==============================] - 0s 4ms/step - loss: 199.7470 - mse: 199.7470
# Epoch 4/100
# 15/15 [==============================] - 0s 4ms/step - loss:
# Epoch 37/100
# 15/15 [==============================] - 0s 6ms/step - loss: 10.6331 - mse: 10.6331
# Epoch 38/100
# 15/15 [==============================] - 0s 6ms/step - loss: 10.4232 - mse: 10.4232
# Epoch 39/100
# 15/15 [==============================] - 0s 6ms/step - loss: 10.2511 - mse: 10.2511
# Epoch 40/100
# 15/15 [==============================] - 0s 6ms/step - loss: 10.1065 - mse: 10.1065
# Epoch 41/100
# 15/15 [==============================] - 0s 7ms/step - loss: 9.9284 - mse: 9.9284
# Epoch 42/100
# 15/15 [==============================] - 0s 7ms/step - loss: 9.7774 - mse: 9.7774
# Epoch 43/100
# 15/15 [==============================] - 0s 7ms/step - loss: 9.6049 - mse: 9.6049
# Epoch 44/100
# 15/15 [==============================] - 0s 7ms/step - loss: 9.4798 - mse: 9.4798
# Epoch 45/100
# 15/15 [==============================] - 0s 6ms/step - loss: 9.3076 - mse: 9.3076
# Epoch 46/100
# 15/15 [==============================] - 0s 7ms/step - loss: 9.1569 - mse: 9.1570
# Epoch 47/100
# 15/15 [==============================] - 0s 7ms/step - loss: 9.0318 - mse: 9.0318
# Epoch 48/100
# 15/15 [==============================] - 0s 7ms/step - loss: 8.8437 - mse: 8.8437
# Epoch 49/100
# 15/15 [==============================] - 0s 7ms/step - loss: 8.6880 - mse: 8.6880
# Epoch 50/100
# 15/15 [==============================] - 0s 7ms/step - loss: 8.5497 - mse: 8.5497
# Epoch 51/100
# 15/15 [==============================] - 0s 8ms/step - loss: 8.3839 - mse: 8.3839
# Epoch 52/100
# 15/15 [==============================] - 0s 8ms/step - loss: 8.2561 - mse: 8.2561
# Epoch 53/100
# 15/15 [==============================] - 0s 9ms/step - loss: 8.1463 - mse: 8.1463
# Epoch 54/100
# 15/15 [==============================] - 0s 6ms/step - loss: 7.9662 - mse: 7.9662
# Epoch 55/100
# 15/15 [==============================] - 0s 4ms/step - loss: 7.8360 - mse: 7.8360
# Epoch 56/100
# 15/15 [==============================] - 0s 4ms/step - loss: 7.7126 - mse: 7.7126
# Epoch 57/100
# 15/15 [==============================] - 0s 5ms/step - loss: 7.5622 - mse: 7.5622
# Epoch 58/100
# 15/15 [==============================] - 0s 4ms/step - loss: 7.4341 - mse: 7.4341
# Epoch 59/100
# 15/15 [==============================] - 0s 4ms/step - loss: 7.3045 - mse: 7.3045
# Epoch 60/100
# 15/15 [==============================] - 0s 4ms/step - loss: 7.1771 - mse: 7.1771
# Epoch 61/100
# 15/15 [==============================] - 0s 6ms/step - loss: 7.0892 - mse: 7.0892
# Epoch 62/100
# 15/15 [==============================] - 0s 8ms/step - loss: 6.9274 - mse: 6.9274
# Epoch 63/100
# 15/15 [==============================] - 0s 7ms/step - loss: 6.8496 - mse: 6.8496
# Epoch 64/100
# 15/15 [==============================] - 0s 9ms/step - loss: 6.6956 - mse: 6.6956
# Epoch 65/100
# 15/15 [==============================] - 0s 7ms/step - loss: 6.5803 - mse: 6.5803
# Epoch 66/100
# 15/15 [==============================] - 0s 3ms/step - loss: 6.4817 - mse: 6.4817
# Epoch 67/100
# 15/15 [==============================] - 0s 3ms/step - loss: 6.3627 - mse: 6.3627
# Epoch 68/100
# 15/15 [==============================] - 0s 3ms/step - loss: 6.2701 - mse: 6.2701
# Epoch 69/100
# 15/15 [==============================] - 0s 5ms/step - loss: 6.1631 - mse: 6.1631
# Epoch 70/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.0617 - mse: 6.0617
# Epoch 71/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.9800 - mse: 5.9800
# Epoch 72/100
# 15/15 [==============================] - 0s 7ms/step - loss: 5.8789 - mse: 5.8789
# Epoch 73/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.7941 - mse: 5.7941
# Epoch 74/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.6963 - mse: 5.6963
# Epoch 75/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.6210 - mse: 5.6210
# Epoch 76/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.5468 - mse: 5.5468
# Epoch 77/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.4870 - mse: 5.4870
# Epoch 78/100
# 15/15 [==============================] - 0s 6ms/step - loss: 5.3788 - mse: 5.3788
# Epoch 79/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.3090 - mse: 5.3090
# Epoch 80/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.2936 - mse: 5.2936
# Epoch 81/100
# 15/15 [==============================] - 0s 6ms/step - loss: 5.1576 - mse: 5.1576
# Epoch 82/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.1084 - mse: 5.1084
# Epoch 83/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.0343 - mse: 5.0343
# Epoch 84/100
# 15/15 [==============================] - 0s 5ms/step - loss: 4.9875 - mse: 4.9875
# Epoch 85/100
# 15/15 [==============================] - 0s 5ms/step - loss: 4.9032 - mse: 4.9032
# Epoch 86/100
# 15/15 [==============================] - 0s 5ms/step - loss: 4.8580 - mse: 4.8580
# Epoch 87/100
# 15/15 [==============================] - 0s 5ms/step - loss: 4.7995 - mse: 4.7995
# Epoch 88/100
# 15/15 [==============================] - 0s 5ms/step - loss: 4.8022 - mse: 4.8022
# Epoch 89/100
# 15/15 [==============================] - 0s 5ms/step - loss: 4.7434 - mse: 4.7434
# Epoch 90/100
# 15/15 [==============================] - 0s 5ms/step - loss: 4.6565 - mse: 4.6565
# Epoch 91/100
# 15/15 [==============================] - 0s 3ms/step - loss: 4.5697 - mse: 4.5697
# Epoch 92/100
# 15/15 [==============================] - 0s 5ms/step - loss: 4.5114 - mse: 4.5114
# Epoch 93/100
# 15/15 [==============================] - 0s 4ms/step - loss: 4.4829 - mse: 4.4829
# Epoch 94/100
# 15/15 [==============================] - 0s 4ms/step - loss: 4.4213 - mse: 4.4213
# Epoch 95/100
# 15/15 [==============================] - 0s 5ms/step - loss: 4.4281 - mse: 4.4281
# Epoch 96/100
# 15/15 [==============================] - 0s 4ms/step - loss: 4.3490 - mse: 4.3490
# Epoch 97/100
# 15/15 [==============================] - 0s 4ms/step - loss: 4.2892 - mse: 4.2892
# Epoch 98/100
# 15/15 [==============================] - 0s 4ms/step - loss: 4.2320 - mse: 4.2320
# Epoch 99/100
# 15/15 [==============================] - 0s 4ms/step - loss: 4.1844 - mse: 4.1844
# Epoch 100/100
# 15/15 [==============================] - 0s 5ms/step - loss: 4.1387 - mse: 4.1387

# %%
#evaluate the model

print(model.evaluate(x_test, y_test))
# Out:
# 2/2 [==============================] - 0s 12ms/step - loss: 3.4308 - mse: 3.4308
# [3.430788516998291, 3.430788516998291]

# %%
#prediction with the trained model

predictions = model.predict(x_test)

print(predictions)
# Out:
# 2/2 [==============================] - 0s 8ms/step
# [[12.836191 ]
#  [10.677662 ]
#  [19.829416 ]
#  [ 8.567327 ]
#  [10.11726  ]
#  [11.553261 ]
#  [ 8.906866 ]
#  [15.659282 ]
#  [16.952553 ]
#  [20.49367  ]
#  [11.557491 ]
#  [ 9.508297 ]
#  [23.244991 ]
#  [ 6.2260275]
#  [10.6007595]
#  [15.599563 ]
#  [11.595391 ]
#  [20.914469 ]
#  [ 9.14632  ]
#  [17.066166 ]
#  [22.804134 ]
#  [17.340506 ]
#  [ 8.071889 ]
#  [15.451191 ]
#  [13.175919 ]
#  [14.433027 ]
#  [15.041609 ]
#  [14.206842 ]
#  [11.241621 ]
#  [22.672716 ]
#  [15.056967 ]
#  [10.0035305]
#  [ 9.905291 ]
#  [15.13973  ]
#  [19.036648 ]
#  [11.883723 ]
#  [10.889605 ]
#  [12.641732 ]
#  [19.685465 ]
#  [18.736904 ]
#  [16.914469 ]
#  [12.471794 ]
#  [ 9.765657 ]
#  [19.025513 ]
#  [12.653308 ]
#  [16.190462 ]
#  [19.539621 ]
#  [ 6.5059977]
#  [10.239914 ]
#  [11.171192 ]]
