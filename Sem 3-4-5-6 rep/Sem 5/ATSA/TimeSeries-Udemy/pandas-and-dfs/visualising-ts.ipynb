# %%
import numpy as np
import pandas as pd

# %%
starbucks = pd.read_csv("D:/UDEMY_TSA_FINAL/Data/starbucks.csv", parse_dates=True, index_col='Date')

# %%
starbucks.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
starbucks['Close'].plot(); #semicolon removes the <AxesSubplot/matplotlib info> part

# %%
starbucks['Volume'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
title = 'TITLE'
ylabel = 'Y LABEL'
xlabel = 'X LABEL'

# %%
ax = starbucks['Close'].plot(figsize=(12, 6), title=title)
ax.set(xlabel=xlabel, ylabel=ylabel)
ax.autoscale(axis='y', tight=True)

# %%
a = starbucks['Close']['2017-01-01': '2017-12-31'].plot(figsize=(12, 4))

# %%
starbucks['Close'].plot(figsize=(12, 4), xlim=['2017-01-01','2017-12-31'])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Line style

starbucks['Close'].plot(figsize=(12, 4), xlim=['2017-01-01','2017-12-31'], ls='dotted')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### XTicks

# %%
from matplotlib import dates

# %%
starbucks['Close'].plot(xlim=['2017-01-01','2017-03-01'], ylim=[50, 60], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ax = starbucks['Close'].plot(xlim=['2017-01-01','2017-03-01'], ylim=[50, 60], figsize=(12, 5))
ax.set(xlabel='')
ax.xaxis.set_major_locator(dates.WeekdayLocator(byweekday=0))

# %% [markdown]
# #### Formatting

# %%
ax = starbucks['Close'].plot(xlim=['2017-01-01','2017-03-01'], ylim=[50, 60], figsize=(12, 5))
ax.set(xlabel='')
ax.xaxis.set_major_locator(dates.WeekdayLocator(byweekday=0))
ax.xaxis.set_major_formatter(dates.DateFormatter('%a-%B-%d'))

# %%
ax = starbucks['Close'].plot(xlim=['2017-01-01','2017-03-01'], ylim=[50, 60], figsize=(12, 5))
ax.set(xlabel='')
ax.xaxis.set_major_locator(dates.WeekdayLocator(byweekday=0))
ax.xaxis.set_major_formatter(dates.DateFormatter('%d'))

ax.xaxis.set_minor_locator(dates.MonthLocator())
ax.xaxis.set_minor_formatter(dates.DateFormatter('\n\n%b'))
