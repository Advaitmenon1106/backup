# %%
import pandas as pd

# %%
starbucks = pd.read_csv("D:/UDEMY_TSA_FINAL/Data/starbucks.csv", parse_dates=True, index_col='Date')

# %%
starbucks.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
starbucks['Close'].plot(figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
starbucks.rolling(window=7).mean().head(15)
# Out:
#                 Close        Volume
# Date
# 2015-01-02        NaN           NaN
# 2015-01-05        NaN           NaN
# 2015-01-06        NaN           NaN
# 2015-01-07        NaN           NaN
# 2015-01-08        NaN           NaN
# 2015-01-09        NaN           NaN
# 2015-01-12  37.616786  1.238222e+07
# 2015-01-13  37.578786  1.297288e+07
# 2015-01-14  37.614786  1.264020e+07
# 2015-01-15  37.638114  1.270624e+07
# 2015-01-16  37.600114  1.260380e+07
# 2015-01-20  37.515786  1.225634e+07
# 2015-01-21  37.615786  9.868837e+06
# 2015-01-22  37.783114  1.185335e+07
# 2015-01-23  38.273129  1.571999e+07

# %% [markdown]
# ```
# 	        Close	    Volume
# Date
# 2015-01-02	NaN	        NaN
# 2015-01-05	NaN	        NaN
# 2015-01-06	NaN	        NaN
# 2015-01-07	NaN	        NaN
# 2015-01-08	NaN	        NaN
# 2015-01-09	NaN	        NaN
# 2015-01-12	37.616786	1.238222e+07
# 2015-01-13	37.578786	1.297288e+07
# 2015-01-14	37.614786	1.264020e+07
# 2015-01-15	37.638114	1.270624e+07
# 2015-01-16	37.600114	1.260380e+07
# 2015-01-20	37.515786	1.225634e+07
# 2015-01-21	37.615786	9.868837e+06
# 2015-01-22	37.783114	1.185335e+07
# 2015-01-23	38.273129	1.571999e+07
# ```
# Here...
#
# - 37.616786 is the average closing of 2nd Jan to 9th Jan
# - 37.578786 is the average closing of 5th Jan to 12th Jan

# %%
starbucks['Close'].plot(figsize=(12, 5))
starbucks['Close'].rolling(window=7).mean().plot()
starbucks['Close'].rolling(window=30).mean().plot()
starbucks['Close'].rolling(window=60).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Expanding

# %%
starbucks['Close'].expanding().mean().plot(figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# A point on the plot is the average of all values before it

# %%
starbucks['Close'].expanding().mean()
# Out:
# Date
# 2015-01-02    38.006100
# 2015-01-05    37.642100
# 2015-01-06    37.419667
# 2015-01-07    37.535950
# 2015-01-08    37.727980
#                 ...
# 2018-12-24    54.032419
# 2018-12-26    54.041439
# 2018-12-27    54.050561
# 2018-12-28    54.059854
# 2018-12-31    54.070133
# Name: Close, Length: 1006, dtype: float64

# %%
print(starbucks['Close'].head())
print(starbucks['Close'].loc['2015-01-05':])
# Out:
# Date
# 2015-01-02    38.0061
# 2015-01-05    37.2781
# 2015-01-06    36.9748
# 2015-01-07    37.8848
# 2015-01-08    38.4961
# Name: Close, dtype: float64
# Date
# 2015-01-05    37.2781
# 2015-01-06    36.9748
# 2015-01-07    37.8848
# 2015-01-08    38.4961
# 2015-01-09    37.2361
#                ...
# 2018-12-24    60.5600
# 2018-12-26    63.0800
# 2018-12-27    63.2000
# 2018-12-28    63.3900
# 2018-12-31    64.4000
# Name: Close, Length: 1005, dtype: float64
