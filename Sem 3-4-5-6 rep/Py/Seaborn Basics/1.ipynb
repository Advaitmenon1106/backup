# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Windmill1.csv")
x = df["Wind"]
y = df["Power"]
sns.regplot(x=df["Wind"], y=df["Power"])
# Out:
# <AxesSubplot:xlabel='Wind', ylabel='Power'>

# %%
sns.lmplot(data= df, x="Wind", y="Power")
