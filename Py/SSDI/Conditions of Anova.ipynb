# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = np.random.normal(size=10000)

# %%
a
# Out:
# array([-0.17866111, -0.91949724, -1.01048425, ...,  1.00119713,
#         1.92368138,  0.0626994 ])

# %%
plt.hist(a)
# Out:
# (array([2.000e+00, 1.400e+01, 1.650e+02, 8.950e+02, 2.298e+03, 3.211e+03,
#         2.298e+03, 9.300e+02, 1.660e+02, 2.100e+01]),
#  array([-4.525797 , -3.7039016, -2.8820062, -2.0601108, -1.2382154,
#         -0.41632  ,  0.4055754,  1.2274708,  2.0493662,  2.8712616,
#          3.693157 ]),
#  <BarContainer object of 10 artists>)

# %%
from scipy import stats
import statsmodels.api as sm
stats.shapiro(a)

#H0: Normally distributed
#Ha: Not normally dist
# Out:
# ShapiroResult(statistic=0.9998770356178284, pvalue=0.9054635167121887)

# %%
df1 = np.random.normal(10, 2, 5)
df2 = np.random.normal(10, 6, 5)

# %%
stats.levene(df1, df2)
# Out:
# LeveneResult(statistic=2.9405716239835678, pvalue=0.1247233899982848)
