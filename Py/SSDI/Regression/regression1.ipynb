# %%
import numpy as np #arrays
import pandas as pd #
import matplotlib.pyplot as plt #plot
import seaborn as sns #to check non linear relation
import sklearn.linear_model as lm #
import statsmodels.formula.api as smf #all info (confidence levels, etc)
import statsmodels.api as sm #

# %%
df = pd.read_csv("Advertising.csv")
print(df)
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
sns.regplot(df, x=df['TV'], y=df['Sales'], order=10)
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Sales'>

# %%
df2 = pd.read_csv('C:/Users/Kavita manoj/OneDrive/Desktop/Py/SSDI/ANOVA/AutoDataset.csv', na_values='?').dropna()
print(df2)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 387  27.0          4         140.0          86    2790          15.6    82
# 388  44.0          4          97.0          52    2130          24.6    82
# 389  32.0          4         135.0          84    2295          11.6    82
# 390  28.0          4         120.0          79    2625          18.6    82
# 391  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
sns.regplot(df2, x=df2.horsepower, y=df2.mpg, order=4)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.regplot(df2, x=df2.horsepower, y=df2.mpg, order=2)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %% [markdown]
# Linear regression on advertisement dataset

# %%
lr=lm.LinearRegression()
X = df.TV.values
Y = df.Sales.values

# %%
X = df.TV.values.reshape(-1, 1)
X.shape
# Out:
# (200, 1)

# %%
lr.fit(X,Y)
lr.fit_intercept
lr.coef_
# Out:
# array([0.04753664])

# %%
print(lr.intercept_)
# Out:
# 7.032593549127695

# %%
fit1 = smf.ols('Sales~TV', data=df).fit()

# %%
fit1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Wed, 08 Mar 2023   Prob (F-statistic):           1.47e-42
# Time:                        11:39:37   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.0326      0.458     15.360      0.000       6.130       7.935
# ...

# %%
fit2 = smf.ols('Sales~TV+Newspaper', data=df).fit()
fit2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.646
# Model:                            OLS   Adj. R-squared:                  0.642
# Method:                 Least Squares   F-statistic:                     179.6
# Date:                Wed, 08 Mar 2023   Prob (F-statistic):           3.95e-45
# Time:                        11:39:37   Log-Likelihood:                -509.89
# No. Observations:                 200   AIC:                             1026.
# Df Residuals:                     197   BIC:                             1036.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.7749      0.525     10.993      0.000       4.739       6.811
# ...

# %%
fit3 = smf.ols('Sales~TV+Radio+TV*Radio', data=df).fit()
fit3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.967
# Method:                 Least Squares   F-statistic:                     1963.
# Date:                Wed, 08 Mar 2023   Prob (F-statistic):          6.68e-146
# Time:                        11:39:37   Log-Likelihood:                -270.14
# No. Observations:                 200   AIC:                             548.3
# Df Residuals:                     196   BIC:                             561.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.7502      0.248     27.233      0.000       6.261       7.239
# ...

# %%
print(df2)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 387  27.0          4         140.0          86    2790          15.6    82
# 388  44.0          4          97.0          52    2130          24.6    82
# 389  32.0          4         135.0          84    2295          11.6    82
# 390  28.0          4         120.0          79    2625          18.6    82
# 391  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
fitAuto1 = smf.ols('mpg~displacement+horsepower+weight+acceleration', data=df2).fit()
fitAuto1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.707
# Model:                            OLS   Adj. R-squared:                  0.704
# Method:                 Least Squares   F-statistic:                     233.4
# Date:                Wed, 08 Mar 2023   Prob (F-statistic):          9.63e-102
# Time:                        11:39:38   Log-Likelihood:                -1120.6
# No. Observations:                 392   AIC:                             2251.
# Df Residuals:                     387   BIC:                             2271.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
fitAuto1 = smf.ols('mpg~displacement+horsepower+weight+acceleration+displacement*horsepower*weight*acceleration', data=df2).fit()
fitAuto1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.778
# Model:                            OLS   Adj. R-squared:                  0.769
# Method:                 Least Squares   F-statistic:                     87.69
# Date:                Wed, 08 Mar 2023   Prob (F-statistic):          1.22e-112
# Time:                        11:39:38   Log-Likelihood:                -1066.5
# No. Observations:                 392   AIC:                             2165.
# Df Residuals:                     376   BIC:                             2228.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# ...

# %%
fitAuto1 = smf.ols('mpg~displacement+horsepower+weight+acceleration', data=df2).fit()
fitAuto1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.707
# Model:                            OLS   Adj. R-squared:                  0.704
# Method:                 Least Squares   F-statistic:                     233.4
# Date:                Wed, 08 Mar 2023   Prob (F-statistic):          9.63e-102
# Time:                        11:39:38   Log-Likelihood:                -1120.6
# No. Observations:                 392   AIC:                             2251.
# Df Residuals:                     387   BIC:                             2271.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
fitAuto1 = smf.ols('mpg~displacement+horsepower+weight+displacement*horsepower*weight*acceleration', data=df2).fit()
fitAuto1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.778
# Model:                            OLS   Adj. R-squared:                  0.769
# Method:                 Least Squares   F-statistic:                     87.69
# Date:                Wed, 08 Mar 2023   Prob (F-statistic):          1.22e-112
# Time:                        11:39:38   Log-Likelihood:                -1066.5
# No. Observations:                 392   AIC:                             2165.
# Df Residuals:                     376   BIC:                             2228.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# ...

# %%
fitAuto1 = smf.ols('mpg~displacement+horsepower+weight+displacement+displacement*horsepower*weight*displacement', data=df2).fit()
fitAuto1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.758
# Model:                            OLS   Adj. R-squared:                  0.754
# Method:                 Least Squares   F-statistic:                     171.9
# Date:                Wed, 08 Mar 2023   Prob (F-statistic):          3.73e-114
# Time:                        11:39:38   Log-Likelihood:                -1083.1
# No. Observations:                 392   AIC:                             2182.
# Df Residuals:                     384   BIC:                             2214.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
"""df2['horsepower'] = df2['horsepower']**2
fitAuto1 = smf.ols('mpg~displacement*horsepower*weight*cylinders*year*acceleration', data=df2).fit()
fitAuto1.summary()"""
df2['horsepower'] = np.sqrt(df2['horsepower'])
# Out:
# c:\Users\Kavita manoj\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df3 = pd.read_csv('C:/Users/Kavita manoj/OneDrive/Desktop/Py/SSDI/ANOVA/AutoDataset.csv', na_values='?').dropna()
fitAuto1 = smf.ols('mpg~displacement*cylinders*year+horsepower*cylinders*year+horsepower*weight*acceleration+displacement*cylinders*acceleration+horsepower*weight*cylinders*acceleration+horsepower*weight*year*acceleration+horsepower*cylinders*year*acceleration+horsepower*weight*cylinders*year*acceleration', data=df3).fit()
fitAuto1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.889
# Method:                 Least Squares   F-statistic:                     85.31
# Date:                Wed, 08 Mar 2023   Prob (F-statistic):          2.44e-153
# Time:                        12:02:13   Log-Likelihood:                -911.52
# No. Observations:                 392   AIC:                             1899.
# Df Residuals:                     354   BIC:                             2050.
# Df Model:                          37
# Covariance Type:            nonrobust
# ...
#                                                     coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# ...
