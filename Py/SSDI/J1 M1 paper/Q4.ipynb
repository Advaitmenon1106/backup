# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(1)
data1 = 5*np.random.randn(50)+100
data2 = 5*np.random.randn(50)+102
print (data1, data2)
# Out:
# [108.12172682  96.94121793  97.35914124  94.63515689 104.32703815
#   88.49230652 108.72405882  96.1939655  101.59519548  98.75314812
#  107.31053969  89.69929645  98.38791398  98.07972823 105.66884721
#   94.50054366  99.13785896  95.61070791 100.21106873 102.91407607
#   94.49690411 105.72361855 104.5079536  102.51247169 104.50427975
#   96.5813607   99.38554887  95.32115283  98.6605596  102.65177733
#   96.54169624  98.01623237  96.5641365   95.77397179  96.64376935
#   99.93667701  94.41344826 101.17207849 108.29901089 103.7102208
#   99.04082224  95.56185518  96.26420853 108.46227301 100.25403877
#   96.81502177 100.95457742 110.50127568 100.60079476 103.08601555] [103.5008516  100.23875077  96.28740901 100.25328639 100.95552883
#  104.93311596 106.19491707 106.65551041 103.42793663 106.42570582
#   98.2280103  108.26434078 104.5646491  100.50953582 104.44259073
#  101.62214143 107.65814694 109.59908408 112.92787703  95.01751832
# ...

# %%
x1Bar = np.mean(data1)
x2Bar = np.mean(data2)
sd1 = np.std(data1)
sd2 = np.std(data2)
stdError = np.sqrt((sd1**2)/len(data1) + (sd2**2)/len(data2))
# Out:
# 4.847946414790679 3.911758045376709 0.8809589711927702 50 50
