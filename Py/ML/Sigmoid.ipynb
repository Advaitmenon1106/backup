# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def sigmoid (k):
    sig = 1/(1+np.exp(-k))
    return sig

# %%
a = np.array([0, 0.5, 1, 1.5, 2, 2.5, 3, 4, 5, 6, 7, 8, 9, 10])
a = (a-np.mean(a))/np.std(a)
plt.plot(a, sigmoid(a))
